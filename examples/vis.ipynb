# %%
import redframes as rf
import matplotlib.pyplot as plt

raw = rf.load("nfl.csv")

# %%
df = (
    raw
    .group(["Position"])
    .take(10)
    .group(["Position"])
    .summarize({"mean_points": ("Points", rf.compute.mean)})
    .sort(["mean_points"])
    .mutate({"color": lambda row: row["Position"].isin(["WR"])})
    # .replace({"color": {"WR": "red", "RB": "red", "QB": "blue", "K": ""}})
)

df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [18], line 2
#       1 df = (
# ----> 2     raw
#       3     .group(["Position"])
#       4     .take(10)
#       5     .group(["Position"])
#       6     .summarize({"mean_points": ("Points", rf.compute.mean)})
#       7     .sort(["mean_points"])
#       8     .mutate({"color": lambda row: row["Position"].isin(["WR"])})
#       9     # .replace({"color": {"WR": "red", "RB": "red", "QB": "blue", "K": ""}})
#      10 )
#      12 df
#
# File ~/Repos/redframes/redframes/dataframe/__init__.py:50, in _CommonFrameMixin.mutate(self, mutations)
#      49 def mutate(self, /, mutations: dict[str, Callable[..., Any]]) -> DataFrame:
# ---> 50     data = mutate(self._data, mutations)
#      51     return _wrap(data)
#
# File ~/Repos/redframes/redframes/dataframe/verbs/mutate.py:18, in mutate(df, mutations)
#      16 df = df.copy()
# ...

# %%
plt.barh(df["Position"], df["mean_points"]);
